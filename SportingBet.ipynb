# %%
import datetime

import time

from selenium import webdriver
from bs4 import BeautifulSoup

from datetime import datetime

# %%
url = 'https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/brasil-33/s%C3%A9rie-a-5545'

# %%
class SportingBet():
    
    
    def __init__(self, url, filename, sample_time, n_attempts=2):
        self.filename = filename
        self.sample_time = sample_time
        self.n_attempts = n_attempts
        self.sleep_time = sample_time/5
        self.url = url
        self.driver = self._init_chromium_driver()
        
#         self._load_page()
        while(True):
            attempt = 0
            for attempt in range(n_attempts):
                try:
                    self._load_page()
                    print('Página carregou')
                    self.write_games_odds()
                    print('Foi escrito')
                    break
                except:
                    print('Erro!')
                    time.sleep(self.sleep_time)
            
            time.sleep(0.5*self.sample_time-attempt*self.sleep_time)
            
    def _init_chromium_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        return webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)
            
    def _load_page(self):
        print('start...' + datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        self.time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        self.driver.get(self.url)
        time.sleep(self.sleep_time)
        print('Get url ok ')
        # Fucking sleep cause shit download speed
        page_source = self.driver.page_source
        time.sleep(self.sleep_time)
        self.page = BeautifulSoup(page_source, "lxml")
        
    def _write_odds(self):
        with open(self.filename, "a") as f:
            for pg in self.page.find_all('div', class_='option option-indicator ng-star-inserted'):
                f.write(str(pg.getText())+';')
            f.write('\n')
    
    def _write_teams(self):
        with open(self.filename, "a") as f:
            print('Entrou em write teams')
            f.write(self.time+';')
            for pg in self.page.find_all('div', class_='participant'):
                print(str(pg.getText().strip())+';')
                f.write(str(pg.getText().strip())+';')
            
    def write_games_odds(self):
        self._write_teams()
        self._write_odds()

# %%
SportingBet(url, 'sportingbet20201130.txt', 60)
# Out:
# start...2020-12-01 00:13:43
# Get url ok
# Erro!
# start...2020-12-01 00:14:27
# Erro!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1de12f68e7ea> in __init__(self, url, filename, sample_time, n_attempts)
#      16                 try:
# ---> 17                     self._load_page()
#      18                     print('Página carregou')
#
# <ipython-input-5-1de12f68e7ea> in _load_page(self)
#      38         self.driver.get(self.url)
# ---> 39         time.sleep(self.sleep_time)
#      40         print('Get url ok ')
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d2fe1afa75aa> in <module>
# ----> 1 SportingBet(url, 'sportingbet20201130.txt', 60)
#
# <ipython-input-5-1de12f68e7ea> in __init__(self, url, filename, sample_time, n_attempts)
#      22                 except:
#      23                     print('Erro!')
# ---> 24                     time.sleep(self.sleep_time)
#      25
#      26             time.sleep(0.5*self.sample_time-attempt*self.sleep_time)
#
# KeyboardInterrupt:

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)

# %%
url = 'https://br.betano.com/sport/futebol/brasil/brasileirao-serie-b/10017/'
driver.get(url)

# %%
page_source = driver.page_source

# %%
page = BeautifulSoup(page_source, "lxml")

# %%
class Betano():
    
    
    def __init__(self, url, filename, sample_time, n_attempts=2):
        self.filename = filename
        self.sample_time = sample_time
        self.n_attempts = n_attempts
        self.sleep_time = sample_time/5
        self.url = url
        self.driver = self._init_chromium_driver()
        
#         self._load_page()
        while(True):
            attempt = 0
            for attempt in range(n_attempts):
                try:
                    self._load_page()
                    print('Página carregou')
                    self.write_games_odds()
                    print('Foi escrito')
                    break
                except:
                    print('Erro!')
                    time.sleep(self.sleep_time)
            time.sleep(0.5*self.sample_time-attempt*self.sleep_time)
            
    def _init_chromium_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        return webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)
            
    def _load_page(self):
        print('start...' + datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        self.time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        self.driver.get(self.url)
        time.sleep(self.sleep_time)
        print('Get url ok ')
        # Fucking sleep cause shit download speed
        page_source = self.driver.page_source
        time.sleep(self.sleep_time)
        self.page = BeautifulSoup(page_source, "lxml")
        
    def _write_odds(self):
        with open(self.filename, "a") as f:
            for pg in page.find_all('td', class_='table__markets__market'):
                for odd in pg.find_all('span', class_='selections__selection__odd'):
                    print(odd.getText()+';')
                    f.write(odd.getText()+';')
            f.write('\n')
    
    def _write_teams(self):
        with open(self.filename, "a") as f:
            print('Entrou em write teams')
            f.write(self.time+';')
            for pg in page.find_all('th', class_='events-list__grid__info'):
                for team in pg.find_all('span'):
                    print(team.getText().strip()+';')
                    f.write(team.getText().strip()+';')
                    
    def write_games_odds(self):
        self._write_teams()
        self._write_odds()

# %%
Betano(url, 'betano20201201_serieb.txt', 45)
# Out:
# start...2020-12-01 01:54:41
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:55:26
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:56:09
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:56:51
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:57:34
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:58:16
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:58:59
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 01:59:41
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:00:25
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:01:07
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:01:49
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:02:31
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:03:12
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:03:54
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:04:35
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:05:16
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:05:57
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:06:38
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:07:19
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:08:00
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:08:42
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:09:23
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:10:05
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:10:46
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:11:27
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:12:08
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:12:49
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:13:30
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:14:11
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:14:52
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:15:33
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:16:14
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:16:56
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:17:37
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:18:18
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:19:00
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
# start...2020-12-01 02:19:41
# Get url ok
# Página carregou
# Entrou em write teams
# Chapecoense;
# Cuiabá MT;
# Nautico PE;
# Guarani SP;
# Confiança-SE;
# Figueirense SC;
# CRB Maceio;
# CS Alagoana;
# 2.15;
# 2.95;
# 3.75;
# 2.60;
# 3.20;
# 2.67;
# 1.65;
# 3.25;
# 6.40;
# 2.90;
# 3.10;
# 2.50;
# Foi escrito
