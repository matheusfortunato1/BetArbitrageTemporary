# %%
import datetime

import time

from selenium import webdriver
from bs4 import BeautifulSoup

from datetime import datetime

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)

# %%
url = 'https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/brasil-33/s%C3%A9rie-a-5545'

# %%
git config --global user.email "matheusfortunatojb@gmail.com"
git config --global user.name "matheus"

# %%
driver.get(url)

# %%
page_source = driver.page_source

# %%
page = BeautifulSoup(page_source, "lxml")

# %%
page
# Out:
# <html class="fw-ten responsive device-desktop product-sports unauthenticated breadcrumbs-visible landscape ready has-header-messages content-left card-content header-sticky bottom-nav-shown header-sub-navigation" data-domain=".sportingbet.com" lang="pt"><head><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//acdn.adnxs.com/dmp/up/pixie.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Série A Futebol | sportingbet</title>
# <meta content="sportingbet" name="apple-mobile-web-app-title"/>
# <meta content="" name="description"/>
# <script async="" src="https://connect.facebook.net/signals/config/782153335656079?v=2.9.29&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/719112798921529?v=2.9.29&amp;r=stable"></script><script async="" src="//connect.facebook.net/en_US/fbevents.js"></script><script async="" src="//bat.bing.com/bat.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//content.iivt.com/ciwic/sp/sp.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WQZP6R8&amp;l=dataLayer" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-N48RN3R"></script><script>
#         function getCookie(name) {
#             const value = `; ${document.cookie}`;
#             const parts = value.split(`; ${name}=`);
#             if (parts.length === 2) return parts.pop().split(';').shift();
#         }
#         function boot() {
#             const lang = getCookie('lang') || 'en';
#             return fetch(`/${lang}/api/clientconfig`, {
#                 cache: 'no-store',
#                 headers: {
#                     'x-bwin-browser-url': location.href,
#                     'x-bwin-browser-referrer': document.referrer
#                 },
#                 credentials: 'same-origin'
#             })
#             .then(res => res.json())
#                 .then(config => window['clientConfig'] = config)
#             .catch(err => console.error(err));
#         }
#         window['_boot'] = boot();
#     </script>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link as="style" href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;0,800;1,400&amp;family=Roboto+Condensed:wght@300;400;700&amp;display=swap" rel="preload"/> <link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;0,800;1,400&amp;family=Roboto+Condensed:wght@300;400;700&amp;display=swap" rel="stylesheet"/>
# <style>
# </style>
# <style>
# @media screen and (max-width: 480px){
# div.bingo-teaser-sec .disable-left-actor .md-teaser-body .md-teaser-image {
#     background-position: 25%;
# }
# }
# </style>
# <style>
# #historyfreespins  li.btn{
# margin-top:3px
# }
# </style>
# <!-- Hotjar Tracking Code for https://www.sportingbet.com -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:1926922,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script><script async="" src="https://static.hotjar.com/c/hotjar-1926922.js?sv=6"></script>
# <script type="text/javascript">
# {
# var imsgdt = new Date();
# imsgdt.setTime(imsgdt.getTime()+14400000);
# document.cookie = 'trackingAffiliate=4586807; expires=' + imsgdt.toGMTString() + '; domain=sportingbet.com; path=/';
# imsgdt.setTime(imsgdt.getTime()+2577600000);
# document.cookie = 'trackerId=4586807; expires=' + imsgdt.toGMTString() + '; domain=sportingbet.com; path=/';
# imsgdt.setTime(imsgdt.getTime()+28929600000);
# document.cookie = 'bonus-min=%2Fen%2Fsignupbonus%3FtrackerId%3D4586807; expires=' + imsgdt.toGMTString() + '; domain=sportingbet.com; path=/';
# }
# </script>
# <!--sports-->
# <meta content="JsgThWE84tKINac4Lt3xVRn3ZoBIqMfqESbj6fmSBBI" name="google-site-verification"/>
# <!--home-->
# <meta content="KoOIwBMagQ4s6LuiDdOIk28a7pTOJjEvusmmXIVl5Ok" name="google-site-verification"/>
# <style>
# @media screen and (max-width: 767px) {
# .casino-wrapper-sr .races-titles-block .upcomming {
# right: 19px !important;
# }
# .casino-wrapper-sr .races-titles-block .upcomming.uk-see-all{
# right: 12px !important;
# }
# }
# @media screen and (min-width: 768px) {
# .casino-wrapper-sr .races-titles-block .upcomming.uk-see-all {
# right: 5px !important;
# }
# .casino-wrapper-sr .races-titles-block .upcomming {
# right: 15px !important;
# }
# }
# </style>
# <style>
# .embed-overlay-popup .theme-bg-popup .egv-pop-btn-left {
#  cursor:pointer;
# }
#
# .embed-overlay-popup .theme-bg-popup .egv-pop-btn-right {
#     cursor:pointer;
#
# }
# </style>
# <style>
# @media screen and (orientation:portrait) {
#   .slick-slide > .ng-scope{
#     height: auto!important;
#     padding-bottom: 0!important;
#     position: relative;
#   }
#   .slick-slide .teaser-image{
#     height: auto!important;
#   }
#   .slick-slide .terms{
#     bottom: 120px;
#   }
# }
# </style>
# <script type="text/javascript">
# var storeJumioRibbonLastUrl = function()
# {
#      var loc= window.location.href;
#      var d = new Date();
#      var currentDomain = "";
#      d.setTime(d.getTime() + (1*24*60*60*1000));
#      var expires = 'expires='+ d.toUTCString();
# 	 if(window.clientConfig.m2Page !== undefined)
# 	 {
# 	 currentDomain = window.clientConfig.m2Page.domain;
# 	 }
# 	 else {
# 	 currentDomain = window.clientConfig.vnPage.domain;
# 	 }
#      document.cookie = 'jumioRibbonPrevLoc= '+ loc + ';'+ expires +';path=/; domain='+ currentDomain;
#      return true;
# }
# </script>
# <script data-version="v0.02">!function(){var t="data-datalayer-load",e="data-datalayer-click",r="data-datalayer-close",n="data-datalayer-selector",a={index:function(t,e){for(var r=this;null!==r.parentElement;){if(l(r.parentElement,e))return Array.from(r.parentElement.children).indexOf(r)+1;r=r.parentElement}return"not applicable"},attr:function(t,e){var r=e?document.querySelector(e):this;return null===r?"not applicable":r.getAttribute(t[0])||"not applicable"},content:function(t,e){var r=e?document.querySelector(e):this;return null===r?"not applicable":r.innerText||"not applicable"},map:function(t){if(t.length<3||"["!==t[1].substr(0,1)||"["!==t[2].substr(0,1)||"]"!==t[1].substr(t[1].length-1,1)||"]"!==t[2].substr(t[2].length-1,1))return"not applicable";try{var e=t[1].substr(1,t[1].length-2).split(","),r=t[2].substr(1,t[2].length-2).split(",")}catch(e){return console.error(t,e),"not applicable"}var n=e.indexOf(t[0].toString());return n>-1?r[n]:"not applicable"},add:function(t){return t.reduce(function(t,e){return t+parseInt(e,10)},0).toString()},substract:function(t){return t.slice(1).reduce(function(t,e){return t-parseInt(e,10)},parseInt(t[0],10)).toString()}},o=[];function u(t){if("string"==typeof t)try{return JSON.parse(t)}catch(e){return console.error(t,e),{}}return t}function l(t,e){return Array.from(document.querySelectorAll(e)).indexOf(t)>-1}function c(t){var e=this;if("string"==typeof t&&"#"===t.substr(0,1)){var r=function(t){var e=/^([a-zA-Z]+)(\((?:[^)(]+|\((?:[^)(]+|\([^)(]*\))*\))*\))$/,r=t.match(/^#?([a-z]+\((?:[^)(]+|\((?:[^)(]+|\([^)(]*\))*\))*\))(:(.+))?$/);if(null===r)return null;return function t(r,n){var a=r.match(e);return{method:a[1],params:a[2]?a[2].substr(1,a[2].length-2).split(/\,\s?(?![^\(]*\)|[^\[]*\])/).map(function(r){return r.match(e)?t(r,n):r}):[],selector:n}}(r[1],r[3])}(t);return null===r?t:a[r.method]?function t(e){var r=this;var n=e.params.map(function(e){if("object"==typeof e){var n=t.call(r,e);return n}return e});try{return a[e.method].call(this,n,e.selector)}catch(t){return console.error("Problem with helper",selector,t),e}}.call(this,r):t}return t instanceof Array?t.map(c.bind(this)):"object"==typeof t?Object.entries(t).reduce(function(t,r){return t[r[0]]=c.call(e,r[1]),t},{}):t}function i(t,e){return c.call(t,u.call(t,e))}function s(t,e){try{i(t,e);t.addEventListener("click",function(t){dataLayer.push(i(t.target,e))},!0)}catch(r){console.error("Problem parsing dataLayer click event from dom element",t,e)}}self.requestAnimationFrame(function a(){Array.from(document.querySelectorAll("["+t+"]:not(["+t+'=""]):not(['+t+'="true"])')).forEach(function(e){var r=e.getAttribute(t);try{var n=i(e,r);dataLayer.push(n)}catch(t){console.error("Problem parsing dataLayer load event from dom element",e,r)}e.setAttribute(t,"true")}),Array.from(document.querySelectorAll("["+n+"]:not(["+n+'=""]):not(['+n+'="true"])')).forEach(function(t){var r=u(t.getAttribute(n));t.setAttribute(n,"true"),Object.entries(r).forEach(function(t){Array.from(document.querySelectorAll(t[0])).forEach(function(r){r.hasAttribute(e)||(s(r,t[1]),r.setAttribute(e,"true"))})})}),Array.from(document.querySelectorAll("["+e+"]:not(["+e+'=""]):not(['+e+'="true"])')).forEach(function(t){var r=t.getAttribute(e);s(t,r),t.setAttribute(e,"true")}),Array.from(document.querySelectorAll("["+r+"]:not(["+r+'=""]):not(['+r+'="true"])')).forEach(function(t){var e=t.getAttribute(r);try{i(t,e),o.push({event:e,element:t})}catch(r){console.error("Problem parsing dataLayer close event from dom element",t,e)}t.setAttribute(r,"true")}),o=o.filter(function(t){return!!function(t,e){for(;null!==t.parentElement;){if(t.parentElement===e)return!0;t=t.parentElement}return!1}(t.element,document.body)||(dataLayer.push(i(t.element,t.event)),!1)}),self.requestAnimationFrame(a)})}();</script>
# <style>
# @media only screen and (max-width:365px) {
#     .teaser-content .teaser-text{
#           width:180px!important;
#      }
# }
# .botaoMultiplaRapidaMobile {
#     background-image: url(https://scmedia.sportingbet.com/$-$/07f6d8f24ec84233a5a4e12bb2c06705.svg);
#     width: 20px;
#     height: 20px;
#     background-repeat: no-repeat;
#     background-position: right;
#     display: inline-block;
# }
# ms-promo-item.col-6.col-sm-4.col-lg-2.list-item.ng-star-inserted:last-child{
#   background-color:#c2cad0;
#   width:100% !important;
# max-width: 100% !important;
#   flex: auto;
# }
# ms-promo-item.col-6.col-sm-4.col-lg-2.list-item.ng-star-inserted:last-child a {
#     width: 145px;
#     margin: 0px auto;
# }
# #register-banner .signup-bonus { color:white; background-color:#21a9ef!important;}
# .grid-compact-event .event-name{white-space:normal !important;}
# .scoreboard .tournament .participant-name{white-space:normal !important; text-align:left!important;}
# .pc-banner-tile .pc-t-h-cont p.txt-xtr-small{ display:none;}
# .pc-banner-tile .pc-t-h-cont p.txt-xtr-small span{ display:none !important;}
#
# ms-highlights-marquee .marquee-card .card-tennis-live .set-game-scoreboard .card-scoreboard_stats-column .cell{ color:#bbb!important;}
# .promotion-tac-body {
# padding-right:1rem;
# }
# ms-crm-promotion-banner-more-info .description ol {margin-left: 15px;}
# .btn-signpost {
#     color: #0988d1;
#     border: 2px solid #0988d1;
#     padding: 5px 10px;
#     border-radius: 3px;
#     float: right;
#     margin-top: 8px;
#     font-weight: bold;
# }
# @media only screen and (max-width:450px) {
#     .btn-signpost {
#            margin-top: 0px !important;
#      }
# }
# .promo-section .promo-section-nontouch-row, .promo-section .promo-section-touch-row{display:none!important;}
# .contentWrap.black{backround:#fff;}
# </style>
# <script type="text/javascript">
#
# //CHANGE BET GENERATOR POSITION
#
# var interval = setInterval(function() {
# if(document.querySelector('ms-bet-generator-shared-column')) {
#     var miniGames = document.querySelector("ms-minigames-column")
#     var betGenerator = document.querySelector("ms-bet-generator-shared-column")
#     miniGames.insertAdjacentElement("beforebegin", betGenerator)
#     clearInterval(interval);
# 	}
# }, 100);
# 	function openTab(evt, tabId) {
# 	  var i, tabcontent, tablinks;
# 	  tabcontent = document.getElementsByClassName("tabcontent");
# 	  for (i = 0; i < tabcontent.length; i++) {
# 		tabcontent[i].style.display = "none";
# 	  }
# 	  tablinks = document.getElementsByClassName("tablinks");
# 	  for (i = 0; i < tablinks.length; i++) {
# 		tablinks[i].className = tablinks[i].className.replace(" active", "");
# 	  }
# 	  document.getElementById(tabId).style.display = "block";
# 	  evt.currentTarget.className += " active";
# 	}
# 	</script>
# <style>
# #secretquestion .btn.ghost-btn {
#   background: transparent;
#   border: 2px solid #d6d6d7;
#   color: #343236;
#   box-shadow: none;
#   -webkit-box-shadow: none;
#   -moz-box-shadow: none;
# }
# #secretquestion .btn.btn-chat.ghost-btn {
#   background: transparent;
#   border: 2px solid #1284e0;
#   color: #1284e0;
#   box-shadow: none;
# }
# </style>
# <style>
# @media only screen and (max-width: 900px) and (orientation:landscape) {
# .sr-card-widget .sr-card-container-top .sr-card-total-prize .sr-card-counter-bet-box .sr-card-counter,
# .sr-card-widget .sr-card-container-top .sr-card-total-prize .sr-card-counter-bet-box .src-card-min-bet {
# font-size: 13px !important;
# }
# }
# </style>
# <script type="text/javascript">
#     document.cookie = "rm-h=1;path=/;"
# </script>
# <script>
#     function DisplayNoneById(id) {
#         document.getElementById(id).style.display = "none";
#     }
# </script>
# <style>
# @font-face {
#     font-family: "sportsicons-temp";
#     src: url(data:application/x-font-woff;charset=utf-8;base64,...) format('woff');
#     font-weight: normal;
#     font-style: normal;
# }
#
# span.sports-101,
# span.sports-102,
# span.sports-103,
# span.sports-104 {
#     font-family: "sportsicons-temp" !important;
# }
#
# .sports-101:before {
#   content: "\e92a" !important;
# }
# .sports-102:before {
#   content: "\e92b" !important;
# }
# .sports-103:before {
#   content: "\e92c" !important;
# }
# .sports-104:before {
#   content: "\e92d" !important;
# }
#
#
# </style>
# <style>
# .event-detail-header .header-content .alert-icon:not(.alert-enabled) {
#     display: none;
# }
# </style>
# <style>
# 	@font-face {
# 		font-family: 'sportsicons-lottery';
# 		src: url(data:application/x-font-woff;charset=utf-8;base64,...)
# 			format('woff');
# 		font-style: normal;
# 		font-weight: 400;
# 	}
#
# 	.sports-icon.sports-98, .sport-icon.sports-98, .icon .sports-98 {
# 		font-family: sportsicons-lottery !important;
# 	}
#
# 	.sports-98::before {
# 		content: '\e900' !important;
# 	}
# </style>
# <style>
# .app__edit-bet-mode .smart-banner, .popup-on .smart-banner {
# display: none;
# }
# </style>
# <script type="text/javascript">window.external = window.external || {}</script>
# <style>
#   #mypromotions-page .portal-center-wrapper {
#      max-width:768px!important;
#   }
# </style>
# <!-- Via Sitecore -->
# <script async="" src="https://service.maxymiser.net/cdn/bwin/js/mmcore.js"></script><meta content="telephone=no" name="format-detection"/><link href="//www.googletagmanager.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//fonts.googleapis.com" rel="preconnect"/><link href="//connect.facebook.net" rel="preconnect"/><link href="//sdk-cdn.optimove.net" rel="preconnect"/><link href="//gvctracksdk.optimove.net" rel="preconnect"/><link href="//service.maxymiser.net" rel="preconnect"/><link href="//analytics.twitter.com" rel="preconnect"/><link href="//cds-api.sportingbet.com" rel="preconnect"/><link href="//cds-push.sportingbet.com" rel="preconnect"/><style id="css-overrides" type="text/css">.bonus-icon {
#     background: url('https://scmedia.sportingbet.com/$-$/8f1082b658604a1d99117e78e6dd5bf9.png')  no-repeat center center transparent;
#     background-size: contain;
# }
# .bonus-icon.sports,
# .bonus-icon.sportsbook {
#         background-image: url('https://scmedia.sportingbet.com/$-$/697d673525cb4a16ac4d0358a1ca9b97.png');
# }
#
# .bonus-icon.casino,
# .bonus-icon.spins {
#         background-image: url('https://scmedia.sportingbet.com/$-$/2781b69c7245442cbe7ef1d70706b1e7.png')
#     }
#
# .bonus-icon.poker {
#         background-image: url('https://scmedia.sportingbet.com/$-$/3cc1415b306a470c9806557b8b05685f.png');
#     }
#
# .bonus-icon.promotions {
#         background-image: url('https://scmedia.sportingbet.com/$-$/60e0e924a16c4c1c9e19e1c9bc8abd91.png');
#     }
#
# .bonus-icon.cashback {
#         background-image: url('https://scmedia.sportingbet.com/$-$/58373d9909074df28321108b01d60d81.png');
#     }
#
# .bonus-icon.missions {
#         background-image: url('https://scmedia.sportingbet.com/$-$/e68785f1f4b44af89db459ae3f426f08.svg');
#     }
#
# .bonus-icon.raf {
#         background-image: url('https://scmedia.sportingbet.com/$-$/8f1082b658604a1d99117e78e6dd5bf9.png');
#     }
# .brand-logo {
#         background: url('https://scmedia.sportingbet.com/$-$/017a5e847ad041228e88e2486625c698.svg') no-repeat center transparent;
#         background-size: contain;
# }
#
# @media (max-width: 374px) {.navbar-switch-logo.brand-logo {background-image: url('https://scmedia.sportingbet.com/$-$/8edff650f5a643df906c09a69b809ac9.png');} }
#
# .grecaptcha-badge { visibility: hidden; }</style><link href="https://scmedia.sportingbet.com/$-$/7f640e13a15740119e6698a4f9b256bc.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://scmedia.sportingbet.com/$-$/193e5542ed834e7489a003d764ce97dc.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://scmedia.sportingbet.com/$-$/08f276856062443e8ebe881a79959785.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#21a9ef" href="https://scmedia.sportingbet.com/$-$/c43618f86076489484a73fd1e5dc9958.svg" rel="mask-icon"/>
# <link href="https://scmedia.sportingbet.com/$-$/32ff7a67b738420d9669c0013075a963.ico" rel="shortcut icon"/>
# <meta content="#21a9ef" name="msapplication-TileColor"/>
# <meta content="/browserconfig.xml" name="msapplication-config"/>
# <meta content="#21a9ef" name="theme-color"/>
# <link href="https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/brasil-33/s%c3%a9rie-a-5545" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="on" http-equiv="cleartype"/>
# <base href="/"/>
# <script>!function(a,b){"use strict";"undefined"!=typeof exports?b(exports):"function"==typeof define&&define.amd?define(["exports"],b):b(a)}(this,function(a){"use strict";var b="CEROS_SCROLL_PROXY_LOADED";if(!window[b]){window[b]=!0;for(var c="ceros-embedded-viewport:",d={PING:"ping",READY:"ready",POSITION:"position",SCROLL_TO:"scroll-to",GOTO_URL:"goto-url",VARIANT_DETECTION:"variant-detection"},e="data-aspectRatio",f=[],g=document.querySelectorAll("iframe.ceros-experience"),h=function(){i(),j()},i=function(){for(var a=0;a<g.length;a++){var b=g[a],c=k(b),d=c.getAttribute(e);if(!d){var f=o(c.style.paddingBottom);c.setAttribute(e,f)}}},j=function(){for(var a=0;a<g.length;a++){var b=g[a],c=k(b);"true"===b.getAttribute("data-ceros-subpixel-oversize")&&(b.setAttribute("data-ceros-subpixel-oversize","false"),b.style.width=b.getAttribute("data-ceros-subpixel-original-width"),b.style.height=b.getAttribute("data-ceros-subpixel-original-height"));var d=b.getBoundingClientRect(),e=Math.ceil(d.width),f=Math.ceil(d.height),h=d.width!==e||d.height!==f;if(h){b.setAttribute("data-ceros-subpixel-oversize","true"),b.setAttribute("data-ceros-subpixel-original-width",b.style.width),b.setAttribute("data-ceros-subpixel-original-height",b.style.height);var i=o(c.style.paddingBottom);c.style.overflow="hidden",b.style.width=e+"px",b.style.height=Math.ceil(e/i)+"px"}}},k=function(a){return a.parentElement},l=function(a,b){var c=k(a),d="desktop"===b?"data-aspectRatio":"data-"+b+"-aspectRatio",f=c.getAttribute(d);return f||(f=c.getAttribute(e)),f?+f:null},m=function(a,b){var c=l(a,b);c&&n(a,c)},n=function(a,b){var c=k(a),d=o(c.style.paddingBottom);d!==b&&(c.style.paddingBottom=p(b),s())},o=function(a){return 100/parseFloat(a)},p=function(a){return(100/a).toFixed(2)+"%"},q=function(a){var b=a.getBoundingClientRect(),c={top:-b.top,bottom:window.innerHeight-b.top,windowWidth:window.innerWidth,windowHeight:window.innerHeight};z(a,d.POSITION,c)},r=function(){for(var a=0;a<f.length;a++)q(f[a])},s=function(){j();for(var a=0;a<f.length;a++)q(f[a])},t=function(a,b){for(var c=null,d=0;d<a.length;d++)if(a[d].contentWindow===b){c=a[d];break}return c},u=function(a){var b=t(document.getElementsByTagName("iframe"),a);b&&(f.push(b),q(b))},v=function(a,b){var c=t(f,a);if(c){var d=Math.max(0,b.scrollPosition-b.pageHeight+b.visibleHeight),e=c.getBoundingClientRect(),g=window.pageYOffset+e.top,h=window.pageYOffset+e.bottom,i=e.bottom-e.top,j=d*i/b.visibleHeight,k=h-window.innerHeight;window.scroll(0,Math.min(j+g,k))}},w=function(a,b){b.urlOpenInNewWindow?window.open(b.url):window.location=b.url},x=function(a,b){var c=t(f,a);c&&m(c,b.variant)},y=function(a){var b,e;try{b=JSON.parse(a.data),e=b&&b.event&&b.event.substr(0,c.length)===c}catch(f){return}if(e)switch(b.event.substr(c.length)){case d.READY:u(a.source);break;case d.SCROLL_TO:v(a.source,b);break;case d.GOTO_URL:w(a.source,b);break;case d.VARIANT_DETECTION:x(a.source,b)}},z=function(a,b,d){var e={event:c+b};if(d)for(var f in d)d.hasOwnProperty(f)&&(e[f]=d[f]);var g=JSON.stringify(e);a.contentWindow.postMessage(g,"*")},A=document.getElementsByTagName("iframe"),B=0;B<A.length;B++)f.indexOf(-1===A[B])&&z(A[B],d.PING);window.sendViewportPositionEvent=q,window.addEventListener("load",h),window.addEventListener("message",y),window.addEventListener("scroll",r),window.addEventListener("resize",s)}});</script>
# <style type="text/css">
# /*
#   @angular/flex-layout - workaround for possible browser quirk with mediaQuery listeners
#   see http://bit.ly/2sd4HMP
# */
# @media screen and (min-width: 600px), screen and (min-width: 960px), screen and (min-width: 1280px), screen and (min-width: 1600px), screen and (min-width: 1920px), screen and (min-width: 1920px), (max-height: 479px), (min-height: 480px), screen and (min-width: 1920px) and (max-width: 4999.9px), screen and (max-width: 1919.9px), screen and (min-width: 1280px) and (max-width: 1919.9px), screen and (min-width: 1600px) and (max-width: 1919.9px), screen and (max-width: 1599.9px), screen and (max-width: 1279.9px), screen and (min-width: 1280px) and (max-width: 1599.9px), screen and (max-width: 1279.9px), screen and (min-width: 960px) and (max-width: 1279.9px), screen and (max-width: 959.9px), screen and (min-width: 600px) and (max-width: 959.9px), screen and (max-width: 599.9px), screen and (min-width: 0px) and (max-width: 599.9px), print {.fx-query-test{ }}
# </style><link href="/ClientDist/themes/sportingbet/theme.7aad167b5b5994244282.css" rel="stylesheet" type="text/css"/><script id="mmpack.0" src="//service.maxymiser.net/platform/eu/api/mmpackage-1.22.js" type="text/javascript"></script><style id="mm_style_mm_cdApiStyleId_1" media="screen" type="text/css"></style><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/823264876/?random=1606708776283&amp;cv=9&amp;fst=1606708776283&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=600&amp;u_w=800&amp;u_ah=600&amp;u_aw=800&amp;u_cd=24&amp;u_his=3&amp;u_tz=-180&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wgb41&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fsports.sportingbet.com%2Fpt-br%2Fsports%2Ffutebol-4%2Faposta%2Fbrasil-33%2Fs%25C3%25A9rie-a-5545&amp;tiba=sportingbet&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><style>.ngxp__container{display:none;position:absolute;border-radius:3px;border:1px solid grey;box-shadow:0 0 2px rgba(0,0,0,.5);padding:10px}.ngxp__container.ngxp__animation{-webkit-animation:150ms ease-out ngxp-fadeIn;animation:150ms ease-out ngxp-fadeIn}.ngxp__container>.ngxp__arrow{border-color:grey;width:0;height:0;border-style:solid;position:absolute;margin:5px}.ngxp__container[x-placement^=bottom],.ngxp__container[x-placement^=left],.ngxp__container[x-placement^=right],.ngxp__container[x-placement^=top]{display:block}.ngxp__container[x-placement^=top]{margin-bottom:5px}.ngxp__container[x-placement^=top]>.ngxp__arrow{border-width:5px 5px 0;border-right-color:transparent;border-bottom-color:transparent;border-left-color:transparent;bottom:-5px;left:calc(50% - 5px);margin-top:0;margin-bottom:0}.ngxp__container[x-placement^=top]>.ngxp__arrow.__force-arrow{border-right-color:transparent!important;border-bottom-color:transparent!important;border-left-color:transparent!important}.ngxp__container[x-placement^=bottom]{margin-top:5px}.ngxp__container[x-placement^=bottom]>.ngxp__arrow{border-width:0 5px 5px;border-top-color:transparent;border-right-color:transparent;border-left-color:transparent;top:-5px;left:calc(50% - 5px);margin-top:0;margin-bottom:0}.ngxp__container[x-placement^=bottom]>.ngxp__arrow.__force-arrow{border-top-color:transparent!important;border-right-color:transparent!important;border-left-color:transparent!important}.ngxp__container[x-placement^=right]{margin-left:5px}.ngxp__container[x-placement^=right]>.ngxp__arrow{border-width:5px 5px 5px 0;border-top-color:transparent;border-bottom-color:transparent;border-left-color:transparent;left:-5px;top:calc(50% - 5px);margin-left:0;margin-right:0}.ngxp__container[x-placement^=right]>.ngxp__arrow.__force-arrow{border-top-color:transparent!important;border-bottom-color:transparent!important;border-left-color:transparent!important}.ngxp__container[x-placement^=left]{margin-right:5px}.ngxp__container[x-placement^=left]>.ngxp__arrow{border-width:5px 0 5px 5px;border-top-color:transparent;border-bottom-color:transparent;border-right-color:transparent;right:-5px;top:calc(50% - 5px);margin-left:0;margin-right:0}.ngxp__container[x-placement^=left]>.ngxp__arrow.__force-arrow{border-top-color:transparent!important;border-bottom-color:transparent!important;border-right-color:transparent!important}@-webkit-keyframes ngxp-fadeIn{0%{display:none;opacity:0}1%{display:block;opacity:0}100%{display:block;opacity:1}}@keyframes ngxp-fadeIn{0%{display:none;opacity:0}1%{display:block;opacity:0}100%{display:block;opacity:1}}</style><script async="" defer="" src="//sdk-cdn.optimove.net/webconfig/affc1fa33973f5b889ae5883ca4c38f29557fc0815a24b2dbd64b320883e1e59/sportingbetbr.1.0.2.js" type="text/javascript"></script><meta content="index, follow" name="robots"/><script async="" defer="" src="//sdk-cdn.optimove.net/webconfig/prod/sdk-events.js" type="text/javascript"></script></head>
# <body>
# <script type="text/javascript">var dataLayer = [];</script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})
# (window,document,'script','dataLayer','GTM-N48RN3R');
# </script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-N48RN3R" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <vn-app class="app-root" ng-version="9.1.12"><vn-smart-banner><!-- --></vn-smart-banner><vn-dynamic-layout-multi-slot class="slot slot-single slot-messages" slot="messages"><vn-top-messages><vn-content-messages class="content-messages-top" closedcookiekey="vn-tm" cssclassforhtmlnode="has-top-messages"><!-- --></vn-content-messages></vn-top-messages><!-- --><!-- --><vn-header-messages><vn-content-messages class="content-messages-top" closedcookiekey="vn-t" cssclassforhtmlnode="has-header-messages"><div class="content-message-container"><vn-content-message><div class="content-message header-top-promo-banner big-campaign-top-msg" data-id="dj_sports_a_topm_br_br"><!-- --><span class="ui-icon theme-close-i"></span><!-- --><vn-page-matrix class="page-matrix"><vn-pc-image-text class="big-campaign pc-component pc-image-text"><!-- --><!-- --><a class="pc-img-a" href="https://www.sportingbet.com/pt-br/mobileportal/promotions/sports/BR_0000?trid=in13766"><img alt="Sports_Top_Message_Chile" class="pc-img" src="https://scmedia.sportingbet.com/$-$/a5213f43b8234145a91a449549ffcc2b.png?p=width800" width="955"/><!-- --><!-- --></a><!-- --><!-- --><!-- --><div class="pc-txt"><p></p><p></p><div class="reg-big-campaign_message"> <div class="inner-text"> <span class="line1"><em>Abra uma conta e ganhe!</em></span> </div> <a class="btn prominent btn-primary" href="https://www.sportingbet.com/pt-br/mobileportal/promotions/sports/BR_0000?trid=in13740" ng-version="9.1.12">Registre-se!</a> <!--div class="small-tnc"> <div>Exclusivo nuevos usuarios | Valor mínimo depósito USD20 | No aplican métodos Neteller o Skrill</div--> </div> <style> @font-face { font-family: "Druk Wide LCG Web"; src: url("https://scmedia.itsfogo.com/$-$/a1eae7e8cac549aea84a4a4b076875c3.eot"); src: url("https://scmedia.itsfogo.com/$-$/a1eae7e8cac549aea84a4a4b076875c3.eot?#iefix") format("embedded-opentype"), url("https://scmedia.itsfogo.com/$-$/702bf9f3c4744b7faedb214370008716.woff2") format("woff2"), url("https://scmedia.itsfogo.com/$-$/7635b5469d444a48917ab0a02dd65bf6.woff") format("woff"); font-weight: 500; font-style: normal; } .big-campaign-top-msg{ max-width: 600px; margin: 0 auto; border-radius: 0; padding:0!important; background:#000; } .big-campaign-top-msg .reg-big-campaign_message{ overflow: hidden; color: #fff; display: flex; align-items: center; text-align: left; padding-left: 40%; flex-direction: column; width: 100%; font-size: 12px; padding-bottom: 0px; line-height: 1.1; } .big-campaign-top-msg .reg-big-campaign_message .inner-text span.line1 { display: block; font-size: 1rem; font-weight: 500; margin-bottom: 2px; margin-top: 5px; line-height: 1.1; margin-bottom: 5px; } .big-campaign-top-msg em { background-size: cover; color: #fff; /* font-size:1.2rem;*/ font-weight: 700; font-style: normal; margin-right: 20px; } .big-campaign-top-msg .reg-big-campaign_message .btn{ width: auto; max-width: inherit; margin-top: 5px; display: inline-block; font-size: 12px; right:40px; width:85px; position:absolute; color: white; } .big-campaign-top-msg .small-tnc{ position: relative; bottom: 0; width: 165%; left: -20%; font-size: 12px; text-align: center; padding: 10% 5px 5px 5px; } .big-campaign-top-msg img{ border-radius: 0; } .big-campaign-top-msg { margin:0 auto; } .big-campaign-top-msg .ui-icon { color:#fff; } .big-campaign-top-msg .btn-second { display:none!important; } .big-campaign-top-msg { background:#191420 url('https://scmedia.itsfogo.com/$-$/a5213f43b8234145a91a449549ffcc2b.png'); width:100%; background-position: -70px top; background-size: auto 100%; background-repeat: no-repeat; background-attachment: scroll; } .big-campaign-top-msg .pc-img-a { position: absolute; left: 0; top: 0; width: 100%; height: 100%; background-size: 100%; } .big-campaign-top-msg .pc-img-a img { display:none!important; } @media (min-width:768px) { .big-campaign-top-msg { background-position: left top; } .big-campaign-top-msg .reg-big-campaign_message { flex-direction:row; justify-content: space-aro ...
# <p></p></div><!-- --></vn-pc-image-text><!-- --></vn-page-matrix></div></vn-content-message><!-- --></div><!-- --></vn-content-messages><!-- --></vn-header-messages><!-- --><!-- --><!-- --></vn-dynamic-layout-multi-slot><vn-dynamic-layout-single-slot class="slot slot-single slot-header" slot="header" vnelementkey="HEADER_SLOT"><vn-responsive-header><header class="header"><vn-content-messages class="content-messages-header-top" closedcookiekey="vn-ts"><!-- --></vn-content-messages><vn-dynamic-layout-multi-slot class="slot slot-single slot-header_top_items" slot="header_top_items"><!-- --></vn-dynamic-layout-multi-slot><!-- --><nav class="navbar navbar-expand-md"><vn-header-section class="navbar-wrapper-left product-nav-wrapper"><vn-h-logo><a alt="Home" class="h-logo navbar-logo-wrapper" href="https://sports.sportingbet.com/pt-br"><div class="navbar-switch-logo brand-logo"></div></a></vn-h-logo><!-- --><!-- --><!-- --><!-- --><!-- --></vn-header-section><vn-header-section class="navbar-wrapper-right"><vn-h-icon><vn-menu-item class="menu-item" displaymode="icon" iconclass="ui-icon ui-icon-size-xl" section="Header"><a class="menu-item-link" href="https://www.sportingbet.com/pt-br/mobileportal/contact" poppertrigger="none"><i class="ui-icon ui-icon-size-xl help-icon theme-question-i"><!-- --></i><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner"><span class="ui-icon ui-close theme-ex"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-h-icon><!-- --><!-- --><vn-h-button><vn-menu-item class="menu-item" linkclass="header-btn btn" section="Header"><a class="menu-item-link header-btn btn btn-header" href="https://www.sportingbet.com/pt-br/labelhost/login" poppertrigger="none"><!-- --><!-- --><!-- --><span class="menu-item-txt">Entrar</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner"><span class="ui-icon ui-close theme-ex"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-h-button><!-- --><!-- --><vn-h-button><vn-menu-item class="menu-item" linkclass="header-btn btn" section="Header"><a class="menu-item-link header-btn btn btn-primary" href="https://www.sportingbet.com/pt-br/mobileportal/register" poppertrigger="none"><!-- --><!-- --><!-- --><span class="menu-item-txt">Registre-se agora</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner"><span class="ui-icon ui-close theme-ex"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-h-button><!-- --><!-- --><!-- --></vn-header-section><!-- --><!-- --></nav><!-- --><vn-dynamic-layout-multi-slot class="slot slot-single slot-header_bottom_items" slot="header_bottom_items"><ms-navigation><!-- --><div class="az-menu-container"></div></ms-navigation><!-- --><!-- --><m ...
# </div><div class="grid-group-header ng-star-inserted"> X
# </div><div class="grid-group-header ng-star-inserted"> 2
# </div><!-- --></ms-group-header><!-- --><!-- --><!-- --><!-- --></div><!-- --><!-- --><!-- --><ms-event class="grid-event ms-active-highlight ng-star-inserted" swipeable="true"><div class="grid-event-wrapper" style="transition: transform 250ms ease-in-out 0s; transform: translateX(0px);"><a class="grid-info-wrapper" href="/pt-br/sports/eventos/grêmio-goiás-10786144"><ms-event-detail class="grid-event-detail"><ms-event-name class="grid-event-name"><ms-inline-tooltip class="ng-star-inserted"><div class="participants-pair-game"><div class="participant-wrapper ng-star-inserted"><div class="participant-container"><div class="participant"> Grêmio<span class="participant-country"></span></div><!-- --></div><!-- --></div><div class="participant-wrapper ng-star-inserted"><div class="participant-container"><div class="participant"> Goiás<span class="participant-country"></span></div><!-- --></div><!-- --></div><!-- --></div></ms-inline-tooltip><!-- --><!-- --><!-- --><!-- --><!-- --></ms-event-name><div class="badges-wrapper"><ms-event-info class="grid-event-info"><!-- --><!-- --><!-- --><ms-alert class="alert-icon alert-grid-view alert-deselected ng-star-inserted"></ms-alert><!-- --><!-- --><!-- --><ms-event-timer class="grid-event-timer"><ms-prematch-timer class="starting-time timer-badge ng-star-inserted">Hoje / 18:00</ms-prematch-timer><!-- --><!-- --></ms-event-timer><!-- --><span class="bet-builder-icon ng-star-inserted">CRIAR APOSTA</span><!-- --></ms-event-info></div></ms-event-detail><ms-grid-scoreboard class="grid-scoreboard hidden"><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></ms-grid-scoreboard><!-- --></a><!-- --><div class="grid-group-container"><ms-option-group class="grid-option-group grid-group ng-star-inserted"><!-- --><ms-option class="grid-option ng-star-inserted"><ms-event-pick class="grid-option-selectable"><div><!-- --><div class="option option-indicator ng-star-inserted"><ms-font-resizer defaultsize="1" maxchars="6" style="font-size: 1em;">1.34</ms-font-resizer></div><!-- --><!-- --></div></ms-event-pick></ms-option><ms-option class="grid-option ng-star-inserted"><ms-event-pick class="grid-option-selectable"><div><!-- --><div class="option option-indicator ng-star-inserted"><ms-font-resizer defaultsize="1" maxchars="6" style="font-size: 1em;">4.75</ms-font-resizer></div><!-- --><!-- --></div></ms-event-pick></ms-option><ms-option class="grid-option ng-star-inserted"><ms-event-pick class="grid-option-selectable"><div><!-- --><div class="option option-indicator ng-star-inserted"><ms-font-resizer defaultsize="1" maxchars="6" style="font-size: 1em;">9.50</ms-font-resizer></div><!-- --><!-- --></div></ms-event-pick></ms-option><!-- --><!-- --><!-- --></ms-option-group><!-- --><!-- --><!-- --></div><!-- --><!-- --></div></ms-event><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><ms-event class="grid-event ms-active-highlight ng-star-inserted" swipeable="true"><div class="grid-event-wrapper" style="transition: transform 250ms ease-in-out 0s; transform: translateX(0px);"><a class="grid-info-wrapper" href="/pt-br/sports/eventos/vasco-da-gama-ceará-10827855"><ms-event-detail class="grid-event-detail"><ms-event-name class="grid-event-name"><ms-inline-tooltip class="ng-star-inserted"><div class="participants-pair-game"><div class="participant-wrapper ng-star-inserted"><div class="participant-container"><div class="participant"> Vasco da Gama<span class="participant-country"></span></div><!-- --></div><!-- --></div><div class="participant-wrapper ng-star-inserted"><div class="participant-container"><div class="participant"> Ceará<span class="participant-country"></span></div><!-- --></div><!-- --></div><!-- --></div></ms-inline-tooltip><!-- --><!-- --><!-- --><!-- --><!-- --></ms-event-name><div class="badges-wrapper"><ms-event-info class="grid-event-info"><!-- --><!-- --><!-- --><ms-alert class="alert-icon alert-grid-view alert-deselected ng-star-inserted"></ms-alert><!-- --><!-- --><!-- --><ms-event-timer class= ...
# </span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://sports.sportingbet.com/pt-br/sports/futebol-4" poppertrigger="none"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">Futebol</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://sports.sportingbet.com/pt-br/sports/tênis-5" poppertrigger="none"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">Tênis</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://sports.sportingbet.com/pt-br/sports/basquetebol-7" poppertrigger="none"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">Basquete</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><!-- --></vn-footer-menu-section><vn-footer-menu-section class="footer-nav ng-star-inserted"><div class="footer-menu-section-title ng-star-inserted">Promoções</div><!-- --><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link ...
# </div><!-- --><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://www.gvcaffiliates.com/" poppertrigger="none" rel="nofollow" target="_blank"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">Programa de afiliados</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://gvc-plc.com/" poppertrigger="none" rel="nofollow" target="_blank"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">GVC-plc.com</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://gvc-plc.com/investor-relations/" poppertrigger="none" rel="nofollow" target="_blank"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">Investors</span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn-popper-content><!-- --><!-- --><!-- --><!-- --></vn-menu-item></vn-footer-menu-item><vn-footer-menu-item class="ng-star-inserted"><vn-menu-item class="menu-item" imageclass="footer-nav-link-img" linkclass="footer-nav-link" section="Footer"><a class="menu-item-link footer-nav-link ng-star-inserted" href="https://www.gvccareers.com/" poppertrigger="none" rel="nofollow" target="_blank"><!-- --><!-- --><!-- --><span class="menu-item-txt ng-star-inserted">Carreiras </span><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></a><!-- --><!-- --><vn-popper-content closetype="button" showcloselink="false"><popper-content class="ngxp__tooltip tooltip-info"><div aria-hidden="true" class="ngxp__container ngxp__animation" role="popper" style="display: none; opacity: 0;"><!-- --><div class="ngxp__inner ng-star-inserted"><span class="ui-icon ui-close theme-ex ng-star-inserted"></span><!-- --><div><div></div></div><!-- --></div><!-- --><div class="ngxp__arrow"></div></div></popper-content><!-- --></vn ...
# ...
# DIL.create(window.gvcAAM.dilSetup));window.visitor=window.visitor||Visitor.getInstance("B5F91CFE533095E70A490D45@AdobeOrg",{cookieDomain:location.host});window.gvcAAM.deviceID=google_tag_manager["GTM-WQZP6R8"].macro(8);window.gvcAAM.signalObject=window.gvcAAM.removeFalsey({url:google_tag_manager["GTM-WQZP6R8"].macro(9),customerID:google_tag_manager["GTM-WQZP6R8"].macro(10),ovs:google_tag_manager["GTM-WQZP6R8"].macro(11),country:google_tag_manager["GTM-WQZP6R8"].macro(12),language:google_tag_manager["GTM-WQZP6R8"].macro(13),frontend:google_tag_manager["GTM-WQZP6R8"].macro(14),app:window.gvcAAM.app(window.gvcAAM.deviceID||""),referrer:google_tag_manager["GTM-WQZP6R8"].macro(15),
# contactability:google_tag_manager["GTM-WQZP6R8"].macro(16),from:"BASIC"});var customerIDSyncObject={};window.gvcAAM.signalObject.customerID&&(customerIDSyncObject.bwindachds={id:window.gvcAAM.signalObject.customerID,authState:1});if(window.gvcAAM.deviceID){var dsid="DSID_"+window.gvcAAM.appDataSource(window.gvcAAM.signalObject.app);customerIDSyncObject[dsid]={id:window.gvcAAM.deviceID}}visitor.setCustomerIDs(customerIDSyncObject)}catch(a){console.log("Couldn't fire AAM signals")};</script><script id="" src="https://sdk-cdn.optimove.net/websdk/sdk-v1.0.7.js" type="text/javascript"></script>
# <script id="" type="text/javascript">!function(a,b){if(!a.pixie){var c=a.pixie=function(d,e,f){c.actionQueue.push({action:d,actionValue:e,params:f})};c.actionQueue=[];a=b.createElement("script");a.async=!0;a.src="//acdn.adnxs.com/dmp/up/pixie.js";b=b.getElementsByTagName("head")[0];b.insertBefore(a,b.firstChild)}}(window,document);pixie("init","f0483c0e-fca8-4f19-9bed-4477eb87e0e3");</script>
# <script id="" type="text/javascript">pixie("event","PageView");</script>
# <noscript><img src="https://ib.adnxs.com/pixie?pi=f0483c0e-fca8-4f19-9bed-4477eb87e0e3&amp;e=PageView&amp;script=0"/></noscript>
# <script id="" type="text/javascript">try{optimoveSDK.initialize("affc1fa33973f5b889ae5883ca4c38f29557fc0815a24b2dbd64b320883e1e59","sportingbetbr.1.0.2",function(){var a=google_tag_manager["GTM-WQZP6R8"].macro(21);null!=a&&void 0!=a&&""!=a&&(console.log("OP setUserId"),optimoveSDK.API.setUserId(a));a=google_tag_manager["GTM-WQZP6R8"].macro(22);"false"!=google_tag_manager["GTM-WQZP6R8"].macro(23)&&(a=google_tag_manager["GTM-WQZP6R8"].macro(24));optimoveSDK.API.setPageVisit(google_tag_manager["GTM-WQZP6R8"].macro(25).split("?")[0],a,google_tag_manager["GTM-WQZP6R8"].macro(26));dataLayer.push({event:"OptimoveReady",OptimoveInitialised:"true"})},"info")}catch(a){console.log("Optimove SDK error")};</script>
# <script id="ldJson_BreadcrumbList" type="application/ld+json">{"@graph":{"@type":"BreadcrumbList","@context":"http://schema.org","itemListElement":[{"@type":"ListItem","name":"Apostas em Futebol","item":{"@type":"Thing","@id":"https://sports.sportingbet.com/pt-br/sports/futebol-4"},"position":0},{"@type":"ListItem","name":"Competições","item":{"@type":"Thing","@id":"https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/competições"},"position":1},{"@type":"ListItem","name":"Brasil","item":{"@type":"Thing","@id":"https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/brasil-33"},"position":2},{"@type":"ListItem","name":"Série A","item":{"@type":"Thing","@id":"https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/brasil-33/série-a-5545"},"position":3}]}}</script><script id="ldJson_SportsEvent" type="application/ld+json">{"@graph":[{"@type":"SportsEvent","name":"Grêmio - Goiás","@context":"http://schema.org","startDate":"2020-11-30T21:00:00-03:00","url":"https://sports.sportingbet.com/pt-br/sports/eventos/grêmio-goiás-10786144","location":{"@type":"Place","name":"Série A","address":{"@type":"PostalAddress","addressCountry":"Brasil"}}},{"@type":"SportsEvent","name":"Vasco da Gama - Ceará","@context":"http://schema.org","startDate":"2020-11-30T21:00:00-03:00","url":"https://sports.sportingbet.com/pt-br/sports/eventos/vasco-da-gama-ceará-10827855","location":{"@type":"Place","name":"Série A","address":{"@type":"PostalAddress","addressCountry":"Brasil"}}},{"@type":"SportsEvent","name":"Fluminense - Bragantino","@context":"http://schema.org","startDate":"2020-11-30T23:00:00-03:00","url":"https://sports.sportingbet.com/pt-br/sports/eventos/fluminense-bragantino-10819409","location":{"@type":"Place","name":"Série A","address":{"@type":"PostalAddress","addressCountry":"Brasil"}}}]}</script>
# <script id="" type="text/javascript">try{if(null==window.gvc_inhouse||"undefined"==window.gvc_inhouse)(function(a,e,f,g,b,c,d){a[b]||(a.GlobalSnowplowNamespace=a.GlobalSnowplowNamespace||[],a.GlobalSnowplowNamespace.push(b),a[b]=function(){(a[b].q=a[b].q||[]).push(arguments)},a[b].q=a[b].q||[],c=e.createElement(f),d=e.getElementsByTagName(f)[0],c.async=1,c.src=g,d.parentNode.insertBefore(c,d))})(window,document,"script","\/\/content.iivt.com\/ciwic\/sp\/sp.js","gvc_inhouse"),window.gvc_inhouse("newTracker","cf","spcollector.itsfogo.com",{forceSecureTracker:!0,
# eventMethod:"post",postPath:"\/com.snowplowanalytics.snowplow\/tp2",encodeBase64:!1,stateStorageStrategy:"cookie",discoverRootDomain:!0,beacon:!0,respectDoNotTrack:!0,contexts:{performanceTiming:!0}}),window.isfp2Generated="undefined",window.isfp2Generated=!1}catch(a){console.log("Failed GVC_Inhouse_Tracker_initialization")};</script>
# <script id="" type="text/javascript">var removeScript=document.querySelectorAll("#GVC_Inhouse_fp2_js");1<removeScript.length&&removeScript[1].parentNode.removeChild(removeScript[1]);</script>
# <script id="" type="text/javascript">var removeScript=document.querySelectorAll("#GVC_Inhouse_fp3_js");1<removeScript.length&&removeScript[1].parentNode.removeChild(removeScript[1]);</script>
# <iframe height="0" src="//4123103.fls.doubleclick.net/activityi;src=4123103;type=sbpv1;cat=sport005;ord=9481528003169;gtm=2wgb41;auiddc=1848150167.1606708553;~oref=https%3A%2F%2Fsports.sportingbet.com%2Fpt-br%2Fsports%2Ffutebol-4%2Faposta%2Fbrasil-33%2Fs%25C3%25A9rie-a-5545?" style="display: none; visibility: hidden;" width="0"></iframe><script id="GVC_Inhouse_fp2_js" src="https://content.iivt.com/ciwic/sp/fingerprint2.js" type="text/javascript"></script><script id="" type="text/javascript">try{window.gvcAAM.deviceID=google_tag_manager["GTM-WQZP6R8"].macro(33);window.gvcAAM.signalObject=window.gvcAAM.removeFalsey({url:google_tag_manager["GTM-WQZP6R8"].macro(34),customerID:google_tag_manager["GTM-WQZP6R8"].macro(35),ovs:google_tag_manager["GTM-WQZP6R8"].macro(36),country:google_tag_manager["GTM-WQZP6R8"].macro(37),language:google_tag_manager["GTM-WQZP6R8"].macro(38),frontend:google_tag_manager["GTM-WQZP6R8"].macro(39),app:window.gvcAAM.app(window.gvcAAM.deviceID||""),referrer:google_tag_manager["GTM-WQZP6R8"].macro(40),contactability:google_tag_manager["GTM-WQZP6R8"].macro(41),from:"PAGEVIEW"});window.gvcAAM.aamCall=window.gvcAAM.dil.api.signals(window.gvcAAM.signalObject,"c_");
# var customerIDSyncObject={};window.gvcAAM.signalObject.customerID&&(customerIDSyncObject.bwindachds={id:window.gvcAAM.signalObject.customerID,authState:1});if(window.gvcAAM.deviceID){var dsid="DSID_"+window.gvcAAM.appDataSource(window.gvcAAM.signalObject.app);customerIDSyncObject[dsid]={id:window.gvcAAM.deviceID}}visitor.setCustomerIDs(customerIDSyncObject);window.gvcAAM.aamCall.submit()}catch(a){};</script><script id="" type="text/javascript">try{pixie("event","PageView")}catch(a){console.log("AppNexus not yet initialised")};</script><iframe height="0" src="//4123103.fls.doubleclick.net/activityi;src=4123103;type=sbpv1;cat=sport005;ord=8805774171436;gtm=2wgb41;auiddc=1848150167.1606708553;~oref=https%3A%2F%2Fsports.sportingbet.com%2Fpt-br%2Fsports%2Ffutebol-4%2Faposta%2Fbrasil-33%2Fs%25C3%25A9rie-a-5545?" style="display: none; visibility: hidden;" width="0"></iframe><iframe class="aamIframeLoaded" id="destination_publishing_iframe_betandwin_0" name="destination_publishing_iframe_betandwin_0_name" sandbox="allow-scripts allow-same-origin" src="https://betandwin.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fsports.sportingbet.com" style="display: none; width: 0px; height: 0px;" title="Adobe ID Syncing iFrame"></iframe>
# <script id="GVC_Inhouse_fp3_js" src="https://content.iivt.com/ciwic/sp/hashes.min.js" type="text/javascript"></script>
# <script id="" type="text/javascript">try{if(null==window.gvc_inhouse||"undefined"==window.gvc_inhouse)(function(a,e,f,g,b,c,d){a[b]||(a.GlobalSnowplowNamespace=a.GlobalSnowplowNamespace||[],a.GlobalSnowplowNamespace.push(b),a[b]=function(){(a[b].q=a[b].q||[]).push(arguments)},a[b].q=a[b].q||[],c=e.createElement(f),d=e.getElementsByTagName(f)[0],c.async=1,c.src=g,d.parentNode.insertBefore(c,d))})(window,document,"script","\/\/content.iivt.com\/ciwic\/sp\/sp.js","gvc_inhouse"),window.gvc_inhouse("newTracker","cf","spcollector.itsfogo.com",{forceSecureTracker:!0,
# eventMethod:"post",postPath:"\/com.snowplowanalytics.snowplow\/tp2",encodeBase64:!1,stateStorageStrategy:"cookie",discoverRootDomain:!0,beacon:!0,respectDoNotTrack:!0,contexts:{performanceTiming:!0}}),window.isfp2Generated="undefined",window.isfp2Generated=!1}catch(a){console.log("Failed GVC_Inhouse_Tracker_initialization")};</script>
# <script id="" type="text/javascript">var removeScript=document.querySelectorAll("#GVC_Inhouse_fp2_js");1<removeScript.length&&removeScript[1].parentNode.removeChild(removeScript[1]);</script>
# <script id="" type="text/javascript">var removeScript=document.querySelectorAll("#GVC_Inhouse_fp3_js");1<removeScript.length&&removeScript[1].parentNode.removeChild(removeScript[1]);</script>
# <iframe height="0" src="//4123103.fls.doubleclick.net/activityi;src=4123103;type=sbpv1;cat=sport005;ord=6096216393076;gtm=2wgb41;auiddc=1848150167.1606708553;~oref=https%3A%2F%2Fsports.sportingbet.com%2Fpt-br%2Fsports%2Ffutebol-4%2Faposta%2Fbrasil-33%2Fs%25C3%25A9rie-a-5545?" style="display: none; visibility: hidden;" width="0"></iframe><script id="GVC_Inhouse_fp2_js" src="https://content.iivt.com/ciwic/sp/fingerprint2.js" type="text/javascript"></script><script id="" type="text/javascript">try{window.gvcAAM.deviceID=google_tag_manager["GTM-WQZP6R8"].macro(52);window.gvcAAM.signalObject=window.gvcAAM.removeFalsey({url:google_tag_manager["GTM-WQZP6R8"].macro(53),customerID:google_tag_manager["GTM-WQZP6R8"].macro(54),ovs:google_tag_manager["GTM-WQZP6R8"].macro(55),country:google_tag_manager["GTM-WQZP6R8"].macro(56),language:google_tag_manager["GTM-WQZP6R8"].macro(57),frontend:google_tag_manager["GTM-WQZP6R8"].macro(58),app:window.gvcAAM.app(window.gvcAAM.deviceID||""),referrer:google_tag_manager["GTM-WQZP6R8"].macro(59),contactability:google_tag_manager["GTM-WQZP6R8"].macro(60),from:"PAGEVIEW"});window.gvcAAM.aamCall=window.gvcAAM.dil.api.signals(window.gvcAAM.signalObject,"c_");
# var customerIDSyncObject={};window.gvcAAM.signalObject.customerID&&(customerIDSyncObject.bwindachds={id:window.gvcAAM.signalObject.customerID,authState:1});if(window.gvcAAM.deviceID){var dsid="DSID_"+window.gvcAAM.appDataSource(window.gvcAAM.signalObject.app);customerIDSyncObject[dsid]={id:window.gvcAAM.deviceID}}visitor.setCustomerIDs(customerIDSyncObject);window.gvcAAM.aamCall.submit()}catch(a){};</script><script id="" type="text/javascript">try{console.log("OP SPA"),console.log("OP page "+google_tag_manager["GTM-WQZP6R8"].macro(61).split("?")[0]),console.log("OP name "+google_tag_manager["GTM-WQZP6R8"].macro(62)),console.log("OP section "+google_tag_manager["GTM-WQZP6R8"].macro(63)),optimoveSDK.API.setPageVisit(google_tag_manager["GTM-WQZP6R8"].macro(64).split("?")[0],google_tag_manager["GTM-WQZP6R8"].macro(65),google_tag_manager["GTM-WQZP6R8"].macro(66))}catch(a){console.log("page view error")};</script><script id="" type="text/javascript">try{var pages_params={frontend:google_tag_manager["GTM-WQZP6R8"].macro(67),level_1:google_tag_manager["GTM-WQZP6R8"].macro(75)};switch(google_tag_manager["GTM-WQZP6R8"].macro(83)){case "Sports Betting":google_tag_manager["GTM-WQZP6R8"].macro(86)&&(pages_params.level_2=google_tag_manager["GTM-WQZP6R8"].macro(89));google_tag_manager["GTM-WQZP6R8"].macro(92)&&(pages_params.level_3=google_tag_manager["GTM-WQZP6R8"].macro(95));tell(pages_params);optimoveSDK.API.reportEvent("page_levels",pages_params);break;case "Live Betting":google_tag_manager["GTM-WQZP6R8"].macro(98)&&(pages_params.level_2=google_tag_manager["GTM-WQZP6R8"].macro(101));google_tag_manager["GTM-WQZP6R8"].macro(104)&&(pages_params.level_3=google_tag_manager["GTM-WQZP6R8"].macro(107));
# tell(pages_params);optimoveSDK.API.reportEvent("page_levels",pages_params);break;case "Casino":var folders=google_tag_manager["GTM-WQZP6R8"].macro(108).split("/");0>google_tag_manager["GTM-WQZP6R8"].macro(109).indexOf("launchEmbedded")?pages_params.level_2=folders[folders.length-1]:pages_params.level_2=folders[0];tell(pages_params);optimoveSDK.API.reportEvent("page_levels",pages_params);break;case "Live Casino":folders=google_tag_manager["GTM-WQZP6R8"].macro(110).split("/");0>google_tag_manager["GTM-WQZP6R8"].macro(111).indexOf("launchEmbedded")?pages_params.level_2=folders[folders.length-
# 1]:pages_params.level_2=folders[0];tell(pages_params);optimoveSDK.API.reportEvent("page_levels",pages_params);break;case "Poker":tell(pages_params);optimoveSDK.API.reportEvent("page_levels",pages_params);break;case "Deposit":optimoveSDK.API.reportEvent("deposit_start",{});pages_params.level_1="cashier";pages_params.level_2="deposit";pages_params.level_3="start";tell(pages_params);optimoveSDK.API.reportEvent("page_levels",pages_params);break;case "Withdrawal":"CashoutOptions"==google_tag_manager["GTM-WQZP6R8"].macro(112)&&
# (optimoveSDK.API.reportEvent(" withdrawal_start ",{}),pages_params.level_1="cashier",pages_params.level_2="withdrawal",pages_params.level_3="start",tell(pages_params),optimoveSDK.API.reportEvent("page_levels",pages_params))}}catch(a){console.log("pageLevels - Page - pageView error "+a)}function tell(a){};</script>
# <script id="" type="text/javascript">try{pixie("event","PageView")}catch(a){console.log("AppNexus not yet initialised")};</script>
# <script id="" type="text/javascript">try{var fingerprintGenerate=function(){var d=new Hashes.SHA256;Fingerprint2.get(function(a){var c=Fingerprint2.x64hash128(a.map(function(b){return b.value}).join(),31);a=d.hex(a.map(function(b){return b.value}).join());c={schema:"gvc:com.gvcanalytics.gvc\/gvc_global_context\/jsonschema\/1-0-0",data:{fp2:c,fp3:a}};window.isfp2Generated||(window.gvc_inhouse("addGlobalContexts",[c]),window.isfp2Generated=!0);raisePageView()})};window.isfp2Generated?raisePageView():fingerprintGenerate();var raisePageView=function(){window.gvc_inhouse("trackUnstructEvent",
# {schema:"gvc:com.gvcanalytics.gvc\/page_view\/jsonschema\/1-0-0",data:{event:"pageView",balance:"0"}},google_tag_manager["GTM-N48RN3R"].macro(32))}}catch(d){console.log("Failed GVC_Inhouse_PageView")};</script>
# <script id="GVC_Inhouse_fp3_js" src="https://content.iivt.com/ciwic/sp/hashes.min.js" type="text/javascript"></script>
# <script id="" type="text/javascript">try{var fingerprintGenerate=function(){var d=new Hashes.SHA256;Fingerprint2.get(function(a){var c=Fingerprint2.x64hash128(a.map(function(b){return b.value}).join(),31);a=d.hex(a.map(function(b){return b.value}).join());c={schema:"gvc:com.gvcanalytics.gvc\/gvc_global_context\/jsonschema\/1-0-0",data:{fp2:c,fp3:a}};window.isfp2Generated||(window.gvc_inhouse("addGlobalContexts",[c]),window.isfp2Generated=!0);raisePageView()})};window.isfp2Generated?raisePageView():fingerprintGenerate();var raisePageView=function(){window.gvc_inhouse("trackUnstructEvent",
# {schema:"gvc:com.gvcanalytics.gvc\/page_view\/jsonschema\/1-0-0",data:{event:"pageView",balance:"0"}},google_tag_manager["GTM-N48RN3R"].macro(51))}}catch(d){console.log("Failed GVC_Inhouse_PageView")};</script></body></html>

# %%
class SportingBet():
    
    
    def __init__(self, url, filename, sample_time, n_attempts=2):
        self.filename = filename
        self.sample_time = sample_time
        self.n_attempts = n_attempts
        self.sleep_time = sample_time/5
        self.url = url
        self.driver = self._init_chromium_driver()
        
#         self._load_page()
        while(True):
            attempt = 0
            for attempt in range(n_attempts):
                try:
                    self._load_page()
                    print('Página carregou')
                    self.write_games_odds()
                    print('Foi escrito')
                    break
                except:
                    print('Erro!')
                    time.sleep(self.sleep_time)
            
            time.sleep(0.5*self.sample_time-attempt*self.sleep_time)
            
    def _init_chromium_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        return webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)
            
    def _load_page(self):
        print('start...' + datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        self.time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        self.driver.get(self.url)
        time.sleep(self.sleep_time)
        print('Get url ok ')
        # Fucking sleep cause shit download speed
        page_source = self.driver.page_source
        time.sleep(self.sleep_time)
        self.page = BeautifulSoup(page_source, "lxml")
        
    def _write_odds(self):
        with open(self.filename, "a") as f:
            for pg in self.page.find_all('div', class_='option option-indicator ng-star-inserted'):
                f.write(str(pg.getText())+';')
            f.write('\n')
    
    def _write_teams(self):
        with open(self.filename, "a") as f:
            print('Entrou em write teams')
            f.write(self.time+';')
            for pg in self.page.find_all('div', class_='participant'):
                print(str(pg.getText().strip())+';')
                f.write(str(pg.getText().strip())+';')
            
    def write_games_odds(self):
        self._write_teams()
        self._write_odds()

# %%
SportingBet(url, 'sportingbet20201130.txt', 60)
# Out:
# start...2020-11-30 01:05:56
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:07:00
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:07:58
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:08:56
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:09:58
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:11:05
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:12:07
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:13:08
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:14:09
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:15:14
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:16:18
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:17:15
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:18:12
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:19:14
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:20:12
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:21:15
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:22:17
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:23:18
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:24:15
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:25:17
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:26:18
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:27:21
# Get url ok
# Erro!
