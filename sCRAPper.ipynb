# %% [markdown]
# # Notebook destinado a fazer scrap dos dados de diferentes sites de apostas
#
#
# [Sportingbet](http://sportingbet.com/pt-br/) \
# [Bet365](https://www.bet365.com/) \
# [Betway](https://sports.betway.com/pt/sports) \
# [Betfair](betfair.com/sport/) \
# [22bet](https://m.22bet.com/pt/) \
# [Betano](https://br.betano.com/sport/futebol/brasil/brasileirao-serie-a/10016/)

# %%
#import libs
import numpy as np
import pandas as pd
import datetime

from bs4 import BeautifulSoup
from mechanize import Browser

# %% [markdown]
# # SportingBet

# %%
class SportingBet():
    
    
    def __init__(self, url, filename, sample_time, n_attempts=2):
        self.filename = filename
        self.sample_time = sample_time
        self.n_attempts = n_attempts
        self.sleep_time = sample_time/5
        self.url = url
        self.driver = self._init_chromium_driver()
        
#         self._load_page()
        while(True):
            attempt = 0
            for attempt in range(n_attempts):
                try:
                    self._load_page()
                    print('Página carregou')
                    self.write_games_odds()
                    print('Foi escrito')
                    break
                except:
                    print('Erro!')
                    time.sleep(self.sleep_time)
            
            time.sleep(0.5*self.sample_time-attempt*self.sleep_time)
            
    def _init_chromium_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        return webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)
            
    def _load_page(self):
        print('start...' + datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        self.time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        self.driver.get(self.url)
        time.sleep(self.sleep_time)
        print('Get url ok ')
        # Fucking sleep cause shit download speed
        page_source = self.driver.page_source
        time.sleep(self.sleep_time)
        self.page = BeautifulSoup(page_source, "lxml")
        
    def _write_odds(self):
        with open(self.filename, "a") as f:
            for pg in self.page.find_all('div', class_='option option-indicator ng-star-inserted'):
                f.write(str(pg.getText())+';')
            f.write('\n')
    
    def _write_teams(self):
        with open(self.filename, "a") as f:
            print('Entrou em write teams')
            f.write(self.time+';')
            for pg in self.page.find_all('div', class_='participant'):
                print(str(pg.getText().strip())+';')
                f.write(str(pg.getText().strip())+';')
            
    def write_games_odds(self):
        self._write_teams()
        self._write_odds()

# %%
SportingBet('https://sports.sportingbet.com/pt-br/sports/futebol-4/aposta/brasil-33/s%C3%A9rie-a-5545', 'sportingbet20201130.txt', 60)

# %% [markdown]
# # Betfair

# %%
from datetime import datetime
import time 

from mechanize import Browser

from bs4 import BeautifulSoup

from mechanize import Browser

from datetime import datetime

import time

# %%
class BetFair():
    
    
    def __init__(self, url, filename, sample_time, n_attempts=2):
        self.filename = filename
        self.sample_time = sample_time
        self.n_attempts = n_attempts
        sleep_time = 5
        self.url = url
        self.br = Browser()
        
        while(True):
            attempt = 0
            for attempt in range(n_attempts):
                try:
                    self._load_page()
                    self.write_games_odds()
                    break
                except:
                    print('Erro!')
                    time.sleep(sleep_time)
            
            time.sleep(self.sample_time-attempt*sleep_time)
            
        
    def _load_page(self):
        self.time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        page_content = self.br.open(self.url).read()
        page = BeautifulSoup(page_content,"lxml")
        page = page.find_all('div', class_='content-multipick')
        self.page = page[0].find_all('div', class_='details-market market-3-runners')
        
    def _get_games_odds(self, pg):
        
        #TODO: tirar a porra desse slice 
        start = str(pg.find_all('a')[0]).find('data-galabel')
        end = str(pg.find_all('a')[0]).find('data-loader')
        teams = str(pg.find_all('a')[0])[start+14:end-11].split(' x ')
        team1 = teams[0]
        team2 = teams[1]

        x1 = str(pg.find_all('a')[1].find().get_text().replace('\n', ''))
        x2 = str(pg.find_all('a')[2].find().get_text().replace('\n', ''))
        x3 = str(pg.find_all('a')[3].find().get_text().replace('\n', ''))

        return [team1, team2, x1, x2, x3]
        
    def write_games_odds(self):
        for pg in self.page:
            self._write_file(self._get_games_odds(pg))

    def _write_file(self, line):
        try:
            with open(self.filename, "a") as f:
                f.write('\n'+self.time)
                for x in line:
                    f.write(';'+ x)
        except:
            print('Criando arquivo: ' + self.filename)
            with open(self.filename, "w") as f:
                f.write('\n'+self.time)
                for x in line:
                    f.write(';'+ x)

# %%
BetFair('https://www.betfair.com/sport/football/brasil-serie-a/13', 'betfair20201130.txt', 60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-469c818f5d71> in <module>
# ----> 1 BetFair('https://www.betfair.com/sport/football/brasil-serie-a/13', 'betfair20201130.txt', 60)
#
# <ipython-input-3-fc49cdc73626> in __init__(self, url, filename, sample_time, n_attempts)
#      21                     time.sleep(sleep_time)
#      22
# ---> 23             time.sleep(self.sample_time-attempt*sleep_time)
#      24
#      25
#
# KeyboardInterrupt:

# %% [markdown]
# # Betway

# %%
import datetime

import time

from selenium import webdriver
from bs4 import BeautifulSoup

from datetime import datetime

# %%
class Betway():
    
    
    def __init__(self, url, filename, sample_time, n_attempts=2):
        self.filename = filename
        self.sample_time = sample_time
        self.n_attempts = n_attempts
        self.sleep_time = sample_time/5
        self.url = url
        self.driver = self._init_chromium_driver()
        
#         self._load_page()
        while(True):
            attempt = 0
            for attempt in range(n_attempts):
                try:
                    self._load_page()
                    print('Página carregou')
                    self.write_games_odds()
                    print('Foi escrito')
                    break
                except:
                    print('Erro!')
                    time.sleep(self.sleep_time)
            
            time.sleep(0.5*self.sample_time-attempt*self.sleep_time)
            
    def _init_chromium_driver(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--ignore-certificate-errors')
        options.add_argument('--incognito')
        options.add_argument('--headless')
        return webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)
            
    def _load_page(self):
        print('start...' + datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        self.time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        self.driver.get(self.url)
        time.sleep(self.sleep_time)
        print('Get url ok ')
        # Fucking sleep cause shit download speed
        page_source = self.driver.page_source
        time.sleep(self.sleep_time)
        self.page = BeautifulSoup(page_source, "lxml")
        
    def _write_odds(self):
        with open(self.filename, "a") as f:
            for pg in self.page.find_all('div', class_='odds')[1:]:
                f.write(str(pg.getText())+';')
            f.write('\n')
    
    def _write_teams(self):
        with open(self.filename, "a") as f:
            print('Entrou em write teams')
            f.write(self.time+';')
            for pg in self.page.find_all('span', class_='teamNameEllipsisContainer'):
                print(str(pg.find('span').getText())+';')
                f.write(str(pg.find('span').getText())+';')
            
    def write_games_odds(self):
        self._write_teams()
        self._write_odds()

# %%
Betway('https://sports.betway.com/pt/sports/grp/soccer/brazil/brasileiro-serie-a', 'betway20201130.txt', 60)
# Out:
# start...2020-11-30 00:51:28
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:52:24
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:53:19
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:54:14
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:55:09
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:56:04
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:57:00
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:57:55
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:58:50
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 00:59:46
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:00:41
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:01:37
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:02:33
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:03:29
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:04:25
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:05:20
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:06:16
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:07:11
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:08:07
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:09:02
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:09:58
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:10:53
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:11:49
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:12:44
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:13:40
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:14:36
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:15:32
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:16:28
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:17:23
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:18:19
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:19:15
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:20:10
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:21:05
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:22:01
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:22:57
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:23:52
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:24:48
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:25:44
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:26:39
# Get url ok
# Página carregou
# Entrou em write teams
# Grêmio;
# Goiás;
# Vasco da Gama;
# Ceará;
# Fluminense;
# Bragantino;
# Foi escrito
# start...2020-11-30 01:27:35
# Erro!

# %% [markdown]
# # Bet365

# %%
import datetime

import time

from selenium import webdriver
from bs4 import BeautifulSoup

from datetime import datetime

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome("/Users/Matheus/Documents/chromedriver", options=options)

# %%
url = 'https://www.bet365.com/#/AC/B1/C1/D13/E51340799/F2/'

# %%
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-25-4848907ef2cb> in <module>
# ----> 1 driver.get(url)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 300.000
#   (Session info: headless chrome=87.0.4280.66)

# %%
page_source = driver.page_source

# %%
page = BeautifulSoup(page_source, "lxml")
